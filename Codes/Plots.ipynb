# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.gridspec as gridspec
import seaborn as sns

# %% [markdown]
# # RQ1

# %% [markdown]
# ## AUC

# %%
df = pd.read_csv('Output/auc_all_mat_6_bugzilla.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/auc_last_mat_6_bugzilla.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 9,"weight": "bold"},
                     linewidths=.5,
                     ax=ax2,
                     yticklabels=False,
                     cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 9,"weight": "bold"},
                     linewidths=.5, 
                     ax=ax1,
                     cmap=cmap,
                     cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/auc_all_mat_6_columba.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/auc_last_mat_6_columba.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 12,"weight": "bold"},
                     linewidths=.5,
                     ax=ax2,
                     yticklabels=False,
                     cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 12,"weight": "bold"},
                     linewidths=.5, 
                     ax=ax1,
                     cmap=cmap,
                     cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/auc_all_mat_6_jdt.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/auc_last_mat_6_jdt.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5,
                     ax=ax2,
                     yticklabels=False,
                     cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5, 
                     ax=ax1,
                     cmap=cmap,
                     cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/auc_all_mat_6_mozilla.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/auc_last_mat_6_mozilla.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5,
                     ax=ax2,
                     yticklabels=False,
                     cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5, 
                     ax=ax1,
                     cmap=cmap,
                     cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/auc_all_mat_6_platform.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/auc_last_mat_6_platform.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5,
                     ax=ax2,
                     yticklabels=False,
                     cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5, 
                     ax=ax1,
                     cmap=cmap,
                     cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/auc_all_mat_6_postgres.csv',index_col=0)
df = df.iloc[0:16,11:28]
round(df,2)
df2 = pd.read_csv('Output/auc_last_mat_6_postgres.csv',index_col=0)
df2 = df2.iloc[0:16,11:28]
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5,
                     ax=ax2,
                     yticklabels=False,
                     cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                     annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                     linewidths=.5, 
                     ax=ax1,
                     cmap=cmap,
                     cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %% [markdown]
# ## Brier

# %%
df = pd.read_csv('Output/brier_all_mat_6_bugzilla.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/brier_last_mat_6_bugzilla.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 9,"weight": "bold"},
                    linewidths=.5,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 9,"weight": "bold"},
                    linewidths=.5, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/brier_all_mat_6_columba.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/brier_last_mat_6_columba.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 12,"weight": "bold"},
                    linewidths=.5,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 12,"weight": "bold"},
                    linewidths=.5, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/brier_all_mat_6_jdt.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/brier_last_mat_6_jdt.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/brier_all_mat_6_mozilla.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/brier_last_mat_6_mozilla.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/brier_all_mat_6_platform.csv',index_col=0)
round(df,2)
df2 = pd.read_csv('Output/brier_last_mat_6_platform.csv',index_col=0)
round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/brier_all_mat_6_postgres.csv',index_col=0)
df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/brier_last_mat_6_postgres.csv',index_col=0)
df2 = df2.iloc[0:16,11:28]
#round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
plt.subplots_adjust(wspace=0, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.05, 0.95, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.5, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1.2, -0.12, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.05, 0.95, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %% [markdown]
# # RQ2

# %%
family = ["Size"#=c("la", "ld", "lt"),
                         ,"Diffusion" #=c("ns", "nm", "nf", "entropy"),
                         ,"Purpose" #= "fix",
                         ,"History" #=c("ndev","pd","npt"),
                         ,"Author" #=c("exp", #"rexp","sexp")
         ]
family
# Out:
# ['Size', 'Diffusion', 'Purpose', 'History', 'Author']

# %%
df = pd.read_csv('Output/type1_all_jdt.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type1_last_jdt.csv',index_col=0)
#df2 = df2.iloc[0:16,11:28]
#round(df2,2)
plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize=(20,10))
plt.subplots_adjust(wspace=.05, hspace=0)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    ax = sns.heatmap(round(df,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.4,
                     ax=ax2,
                    yticklabels=False,
                    cmap=cmap)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    ax.set_aspect('equal')
    ax.text(0.35, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)
    
with sns.axes_style("white"):
    ax = sns.heatmap(round(df2,2), #vmax=.3, 
                     square=True,
                    annot=True,
                     annot_kws={"size": 10,"weight": "bold"},
                    linewidths=.4, 
                     ax=ax1,
                    cmap=cmap,
                    cbar=False)
    ax.set_ylabel("Six-Month Training Period Breakdown",fontsize=18)
    ax.set_aspect('equal')
    ax.set_yticklabels(list(reversed(range(1, df.shape[1]+1))), fontsize=15)
    ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)    
    plt.text(1, -0.2, "Six-Month Testing Period Breakdown",
         horizontalalignment='center',
         fontsize=18,
         transform = ax1.transAxes)
    ax.text(0.35, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)

# %%
df = pd.read_csv('Output/type1_all_jdt.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type1_last_jdt.csv',index_col=0)
df.index = family
df2.index = family


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)
# Out:
# Text(0.4, 1.2, 'Short Period')

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type2_all_jdt.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type2_last_jdt.csv',index_col=0)
df.index = family
df2.index = family


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)
# Out:
# Text(0.4, 1.2, 'Short Period')

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type1_all_mozilla.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type1_last_mozilla.csv',index_col=0)
df.index = family
df2.index = family


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)
# Out:
# Text(0.4, 1.2, 'Short Period')

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type2_all_mozilla.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type2_last_mozilla.csv',index_col=0)
df.index = family
df2.index = family


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)
# Out:
# Text(0.4, 1.2, 'Short Period')

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type1_all_postgres.csv',index_col=0)
df = df.iloc[:,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type1_last_postgres.csv',index_col=0)
df2 = df2.iloc[:,11:28]
df.index = family
df2.index = family

fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)
# Out:
# Text(0.4, 1.2, 'Short Period')

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type2_all_postgres.csv',index_col=0)
df = df.iloc[:,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type2_last_postgres.csv',index_col=0)
df2 = df2.iloc[:,11:28]
df.index = family
df2.index = family

fig, (ax) = plt.subplots(figsize=(20,5))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,5))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)
# Out:
# Text(0.4, 1.2, 'Short Period')

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
#plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
#plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type1_all_platform.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type1_last_platform.csv',index_col=0)
df.index = family
df2.index = family


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
#plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#           ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
#plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#           ncol=2, mode="expand", borderaxespad=0.)

# %%
df = pd.read_csv('Output/type2_all_platform.csv',index_col=0)
#df = df.iloc[0:16,11:28]
#round(df,2)
df2 = pd.read_csv('Output/type2_last_platform.csv',index_col=0)
df.index = family
df2.index = family


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Long Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(20,10))

ax = sns.heatmap(round(df2,2), #vmax=.3, 
                 square=True,
                annot=True,
                 annot_kws={"size": 20,"weight": "bold"},
                linewidths=.4,
#                 ax=ax2,
                yticklabels=False,
                cmap=cmap)
ax.set_xticklabels(range(1, df2.shape[1]+1), fontsize=15)   
ax.set_yticklabels(family, fontsize=15)
ax.set_aspect('equal')
ax.text(0.4, 1.2, "Short Period", transform=ax.transAxes, fontsize=25,
    verticalalignment='top', bbox=props)

# %%
fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df.transpose().index, df.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df.transpose().index, df.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df.transpose().index, df.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df.transpose().index, df.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df.transpose().index, df.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
# plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#            ncol=2, mode="expand", borderaxespad=0.)
#ax.text(0.4, 1.08, "Long Period", transform=ax.transAxes, fontsize=25,
#    verticalalignment='top', bbox=props)


fig, (ax) = plt.subplots(figsize=(8,5))

plt.plot(df2.transpose().index, df2.transpose().Size, label='Size', lw=3, ls='-', marker='+')
plt.plot(df2.transpose().index, df2.transpose().Diffusion, label='Diffusion', lw=3, ls='--', marker='o')
plt.plot(df2.transpose().index, df2.transpose().Purpose, label='Purpose', lw=3, ls='-', marker='s')
plt.plot(df2.transpose().index, df2.transpose().History, label='History', lw=3, ls='--', marker='1')
plt.plot(df2.transpose().index, df2.transpose().Author, label='Author', ls='-', marker='o', markersize=2)
# plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#            ncol=2, mode="expand", borderaxespad=0.)
